# %%
#Exo1
a=vector([-2,4,8,13])
b=vector([0,1,2,3,4])
c=vector([2,3,4,5,6,7,8,9])

b = vector([0..4])
c = vector([2..9])

b=vector(range(5))
c=vector([i for i in srange (2,10)])

var("z")
v=vector([z,z+1,2*z,z**2])

v.subs(z=2)#v(z=2)
print v
# Out:
# (z, z + 1, 2*z, z^2)

# %%
#Exo2
reset()
#help(vector)
v=vector([0,2,1,5,4,8])
premier=v[0]
quatrieme=v[3]
dernier=v[v.length()-1]

# %%
#Exo3
reset()
#help(vector)
u=vector([0,2,1,5])
u.norm(1)
u.norm(2)
u.norm(infinity)
print norm(u) #norme 2
# Out:
# sqrt(30)

# %%
#Exo4
reset()
x=vector([2,4,5,8,9])
y=vector([2,6,4,7,9])
print x*y, y*x #x.dot_product(y, y.dot_product(x))
a=vector([1,1])
b=vector([1,-1])
c=vector([2,2])
print a.dot_product(b), c.dot_product(b), a.dot_product(c), norm(a)*norm(c)
# Out:
#  185 185
# 0 0 4 4

# %%
#Exo5
M=vector([1.35, 0])
B=vector([3.5,0])
n=vector([2,0])

abs((M-B).dot_product(n))/norm(n)
plot(point((1.5,2.35)))+plot(line([(3.5,0),(3.5,3)]))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# __Hyperplan:__
# * dans le plan (2D), hyperplan =droite (1D)
# * dans l'espace (3D), hyperplan =plan (2D)
# * dans l'espace (nD), hyperplan = (n-1)D
